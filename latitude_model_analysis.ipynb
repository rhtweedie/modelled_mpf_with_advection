# %% [markdown]
# ## Latitude model analysis
#
# This notebook models melt-pond fraction as a function of latitude and sea-ice roughness.
#
# Heather Tweedie
# May 2024
# MSci Dissertation

# %% [markdown]
# Import modules and functions:

# %%
import xarray as xr
import h5py as h5
import pandas as pd 
import numpy as np
import pickle
import matplotlib.pyplot as plt
#import cartopy.crs as ccrs
#import cartopy.feature as cfea
#from pyproj import Transformer
import pyproj
#import datetime
from scipy.interpolate import griddata
from scipy.stats import binned_statistic_2d
import os
#from matplotlib.colors import LinearSegmentedColormap
from mpl_toolkits.basemap import Basemap

# %%
def WGS84toEASE2N(lon, lat):
    proj_EASE2N = pyproj.Proj("+proj=laea +lon_0=0 +lat_0=90 +x_0=0 +y_0=0 +ellps=WGS84 +towgs84=0,0,0,0,0,0,0 +units=m +no_defs")
    proj_WGS84 = pyproj.Proj("+proj=longlat +ellps=WGS84 +datum=WGS84 +no_defs ")
    x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)

    return x, y


def LOAD_MISR_H5(MISR_path):
    file_path = MISR_path
    file = h5.File(file_path, 'r')
    roughness = file['Roughness']['Roughness_2D_svm']
    data = np.array(roughness)
    file.close()
    
    return data


def load_static_MISR(year):
    SPACING = 8
    misr_path = f'/home/ssureen/MISR_data_monthly/April {year} Roughness.h5'
    lon_MISR, lat_MISR, x_MISR, y_MISR = MISR_COORDS(misr_path)

    april_MISR = LOAD_MISR_H5(misr_path)[::SPACING,::SPACING]
    lon_MISR = lon_MISR[::SPACING,::SPACING]
    lat_MISR = lat_MISR[::SPACING,::SPACING]
    x_MISR = x_MISR[::SPACING,::SPACING]
    y_MISR = y_MISR[::SPACING,::SPACING]

    return april_MISR, lon_MISR, lat_MISR, x_MISR, y_MISR


def MISR_COORDS(MISR_path):
    file_path = MISR_path
    file = h5.File(file_path, 'r')
    lon_MISR = np.array(file['GeoLocation']['Longitude'])
    lat_MISR = np.array(file['GeoLocation']['Latitude'])
    x_MISR = np.array(file['GeoLocation']['x'])
    y_MISR = np.array(file['GeoLocation']['y'])
    file.close()
    
    return lon_MISR, lat_MISR, x_MISR, y_MISR


def load_observed_mpf(year, x_MISR, y_MISR):
    if year >= 2017 and year <= 2023:
        path = f'/home/htweedie/melt_ponds/data/OLCI/olci/{year}'
    elif year >= 2002 and year <= 2011:
        path = f'/home/htweedie/melt_ponds/data/MERIS/mecosi/{year}'

    summer_observed_mpf = np.zeros((4, 896*608))
    summer_observed_mpf[0,:] = np.load(f'{path}/mean_05_{year}.npy').ravel()
    summer_observed_mpf[1,:] = np.load(f'{path}/mean_06_{year}.npy').ravel()
    summer_observed_mpf[2,:] = np.load(f'{path}/mean_07_{year}.npy').ravel()
    summer_observed_mpf[3,:] = np.load(f'{path}/mean_08_{year}.npy').ravel()

    mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)

    # retrieve MPF coordinates
    coords = h5.File('/home/htweedie/melt_ponds/data/OLCI/olci/LongitudeLatitudeGrid-n12500-Arctic.h5', 'r')
    lon_mpf =  np.array(coords['Longitudes'])
    lat_mpf = np.array(coords['Latitudes'])
    x_mpf, y_mpf = WGS84toEASE2N(lon_mpf, lat_mpf)

    # interpolate so all arrays are the same size
    mean_observed_mpf = interpolate_to_MISR(x_mpf, y_mpf, mean_observed_mpf, x_MISR, y_MISR)

    return mean_observed_mpf, lon_mpf, lat_mpf, x_mpf, y_mpf


def load_advected_mpf(year):
    # load advected data
    mpf_advected = pd.read_pickle(f'/home/htweedie/melt_ponds/data/forwarded_mpfs/mpf_from_{year}0401_183_days_spacing_8.pkl')

    # subset full mpf dataframe to retrieve just the days to average
    date_from = format_date(year, '05', '01')
    date_to = format_date(year, '08', '31')
    subset_mpf = mpf_advected.loc[date_from:date_to]
    mean_advected_mpf = np.nanmean(subset_mpf, axis=0).reshape(1000,1000)

    return mean_advected_mpf


def load_advected_MISR(year):
    return np.load(f'/home/htweedie/melt_ponds/data/forwarded_mpfs/testing/mean_summer_sir_{year}.npy').reshape(1000,1000)


def interpolate_to_MISR(X_grid_in,Y_grid_in,Z_in,X_grid_out,Y_grid_out): 
    # function interpolates z data in which has shape X_in, Y_in to the same shape as X_out, Y_out
    z = griddata((X_grid_in.ravel(),Y_grid_in.ravel()),Z_in.ravel(),(X_grid_out.ravel(),Y_grid_out.ravel()),'nearest').reshape(1000,1000) 
    # to actually interpolate to MISR, need MISR x, y grid in and to reshape to 8000x8000 but can work with other shapes
    return z


def nanmean(x):
    return np.nanmean(x)


def calculate_binned_averages(mpf, MISR, lat_MISR):

    # Create masks for valid data in each array
    mask1 = ~np.isnan(mpf)  # Invert the NaN values to get a mask of valid data
    mask2 = ~np.isnan(MISR)

    # Create a joint mask where both arrays have valid data
    joint_mask = mask1 & mask2

    # Use the joint mask to apply the mask to both arrays and corresponding latitude
    masked_mpf = np.ma.masked_array(mpf, mask=~joint_mask)
    masked_MISR = np.ma.masked_array(MISR, mask=~joint_mask)
    masked_lat_MISR = np.ma.masked_array(lat_MISR, mask=~joint_mask)

    mpf = masked_mpf.ravel()
    roughness = masked_MISR.ravel()
    lat = masked_lat_MISR.ravel()

    # Define the number of bins for latitude and roughness
    num_lat_bins = 30
    num_rough_bins = 20

    # Calculate the 2D binning and get the average values of mpf in each bin
    averages, _, _, _ = binned_statistic_2d(
        lat,
        roughness,
        mpf,
        statistic = nanmean,
        bins=[num_lat_bins, num_rough_bins],
        range=[[60, 90], [0, 0.5]]
    )

    return averages


def plot_bins(binned_stats, col, min, max, title, label_size, title_size, colorbar=True, colorbar_title=""):
    y_tick_positions = np.linspace(0, 30, 7) 
    x_tick_positions = np.linspace(0, 20, 5)
    y_tick_labels = np.linspace(60, 90, 7) 
    x_tick_labels = np.linspace(0, 0.5, 5)

    plt.xticks(x_tick_positions, x_tick_labels) # Relabel ticks
    plt.yticks(y_tick_positions, y_tick_labels)

    plt.ylabel("Latitude", fontsize=label_size)
    plt.xlabel("Roughness", fontsize=label_size)

    plt.pcolor(binned_stats, cmap=col, vmin=min, vmax=max)
    plt.title(title, fontsize=title_size)

    if colorbar:
        cbar = plt.colorbar()
        cbar.set_label(colorbar_title, fontsize=label_size)


def format_date(year, month, day):
    return f"{year}-{month}-{day} 12:00:00"


def perc_diff(predicted, observed):
    return (predicted - observed) / ((predicted + observed) / 2) * 100


def calc_excl_bin_means(year_to_exclude):
    years = [2010, 2011, 2017, 2018, 2019, 2020]
    if year_to_exclude != 'None':
        years.remove(year_to_exclude)

    annual_static_binned_stats = np.zeros((len(years), 30, 20))
    annual_advected_binned_stats = np.zeros((len(years), 30, 20))

    for i in range(len(years)):
        year = years[i]

        april_MISR, lon_MISR, lat_MISR, x_MISR, y_MISR = load_static_MISR(year)
        mean_advected_MISR = load_advected_MISR(year)
        mean_observed_mpf,_,_,_,_ = load_observed_mpf(year, x_MISR, y_MISR)

        annual_static_binned_stats[i,:,:] = calculate_binned_averages(mean_observed_mpf, april_MISR, lat_MISR)
        annual_advected_binned_stats[i,:,:] = calculate_binned_averages(mean_observed_mpf, mean_advected_MISR, lat_MISR)

    # calculate mean bins:
    mean_static_bins = np.zeros((30, 20))
    mean_advected_bins = np.zeros((30, 20))
    rows = 30
    cols = 20
    for i in range(rows):
        for j in range(cols):
            mean_static_bins[i][j] = np.nanmean(annual_static_binned_stats[:,i,j])
            mean_advected_bins[i][j] = np.nanmean(annual_advected_binned_stats[:,i,j])

    return mean_static_bins, mean_advected_bins


def predict_mpf(MISR, lat, mean_bins):
    # get the bin indices and replace out-of-range indices with nans
    lat_edges = np.linspace(60, 90, num=31) # 30 lat bins
    lat_values = lat.ravel()
    lat_indices = np.digitize(lat_values, lat_edges)
    lat_indices = np.where((lat_indices==0) | (lat_indices==len(lat_edges)), np.nan, lat_indices)

    misr_edges = np.linspace(0, 0.5, num=20) # 20 misr bins
    misr_values = MISR.ravel()
    misr_indices = np.digitize(misr_values, misr_edges)
    misr_indices = np.where((misr_indices==0) | (misr_indices==len(misr_edges)), np.nan, misr_indices)

    predicted_mpf = np.zeros(1000000)
    for i in range(1000000):
        current_misr_index = misr_indices[i]
        current_lat_index = lat_indices[i]
        if not (np.isnan(current_misr_index) or np.isnan(current_lat_index)):
            predicted_mpf[i] = mean_bins[current_lat_index.astype(int)][current_misr_index.astype(int)]
        else:
            predicted_mpf[i] = np.nan

    return predicted_mpf.reshape(1000,1000)


def write_list(path, list):
    if os.path.isfile(path):
        os.remove(path)
    with open(path, 'wb') as f:
        pickle.dump(list, f)

# %% [markdown]
# Load MPF and SIR data and coords:

# %%
YEAR = 2020

april_MISR, lon_MISR, lat_MISR, x_MISR, y_MISR = load_static_MISR(YEAR)
mean_observed_mpf, lon_mpf, lat_mpf, x_mpf, y_mpf = load_observed_mpf(YEAR, x_MISR, y_MISR)
mean_advected_MISR = load_advected_MISR(YEAR)

print(f'\nMean observed MPF: {np.shape(mean_observed_mpf)}')
print(f'Observed April SIR: {np.shape(april_MISR)}')
print(f'Mean advected summer SIR: {np.shape(mean_advected_MISR)}\n')
# Out:
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# Mean observed MPF: (1000, 1000)
# Observed April SIR: (1000, 1000)
# Mean advected summer SIR: (1000, 1000)

# %% [markdown]
# Plot observed summer mpf as a function of lat and sigma, both static and advected:

# %%
fig = plt.figure(figsize=(15,6))

static_binned_stats = calculate_binned_averages(mean_observed_mpf, april_MISR, lat_MISR)
advected_binned_stats = calculate_binned_averages(mean_observed_mpf, mean_advected_MISR, lat_MISR)

plt.subplot(121)
plot_bins(static_binned_stats*100, 'cubehelix_r', 0, 60, f'Static', 16, 20, colorbar=True, colorbar_title='Melt-pond fraction, %')

plt.subplot(122)
plot_bins(advected_binned_stats*100, 'cubehelix_r', 0, 60, f'Advected', 16, 20, colorbar=True, colorbar_title='Melt-pond fraction, %')

plt.subplots_adjust(top=0.8)
plt.suptitle(f'Melt-pond fraction as a function of latitide and roughness, {YEAR}', fontsize=24)
plt.show()
# Out:
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()

# %% [markdown]
# ### Find annual binned averages and plot:

# %%
YEARS = [2010, 2011, 2017, 2018, 2019, 2020]
y_tick_positions = np.linspace(0, 30, 7) 
x_tick_positions = np.linspace(0, 20, 5)
y_tick_labels = np.linspace(60, 90, 7) 
x_tick_labels = np.linspace(0, 0.5, 5)

fig = plt.figure(figsize=(12,8))

annual_static_binned_stats = np.zeros((len(YEARS), 30, 20))
annual_advected_binned_stats = np.zeros((len(YEARS), 30, 20))
for i in range(len(YEARS)):
    year = YEARS[i]
    print(f'Processing {year}...')

    # retrieve April MISR 
    april_MISR = LOAD_MISR_H5(f'/home/ssureen/MISR_data_monthly/April {year} Roughness.h5')[::8,::8]
    print(f'Loaded MISR data')

    # retrieve advected MISR
    mean_advected_MISR = load_advected_MISR(year)

    # retrieve observed MPF 
    if YEAR >= 2017 and YEAR <= 2023:
        path = f'/home/htweedie/melt_ponds/data/OLCI/olci/{YEAR}'
    elif YEAR >= 2002 and YEAR <= 2011:
        path = f'/home/htweedie/melt_ponds/data/MERIS/mecosi/{YEAR}'
    summer_observed_mpf = np.zeros((4, 896*608))
    summer_observed_mpf[0,:] = np.load(f'{path}/mean_05_{YEAR}.npy').ravel()
    summer_observed_mpf[1,:] = np.load(f'{path}/mean_06_{YEAR}.npy').ravel()
    summer_observed_mpf[2,:] = np.load(f'{path}/mean_07_{YEAR}.npy').ravel()
    summer_observed_mpf[3,:] = np.load(f'{path}/mean_08_{YEAR}.npy').ravel()
    mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
    mean_observed_mpf = interpolate_to_MISR(x_mpf, y_mpf, mean_observed_mpf, x_MISR, y_MISR)

    static_binned_stats = calculate_binned_averages(mean_observed_mpf, april_MISR, lat_MISR)
    advected_binned_stats = calculate_binned_averages(mean_observed_mpf, mean_advected_MISR, lat_MISR)

    plt.subplot(2,3,i+1)
    plt.xticks(x_tick_positions, x_tick_labels) # Relabel ticks
    plt.yticks(y_tick_positions, y_tick_labels)

    plt.ylabel("Latitude")
    plt.xlabel("Roughness")

    plt.pcolor(advected_binned_stats, cmap='cubehelix_r', vmin=0, vmax=0.6)
    plt.colorbar()
    plt.title(f'{year}')

    annual_static_binned_stats[i] = static_binned_stats
    annual_advected_binned_stats[i] = advected_binned_stats

fig.tight_layout()
plt.show()

np.save(f'/home/htweedie/melt_ponds/data/binned_stats/static_all_years_bins.npy', annual_static_binned_stats)
np.save(f'/home/htweedie/melt_ponds/data/binned_stats/advected_all_years_bins.npy', annual_advected_binned_stats)

# calculate mean bins:
mean_static_bins = np.zeros((30, 20))
mean_advected_bins = np.zeros((30, 20))
rows = 30
cols = 20
for i in range(rows):
    for j in range(cols):
        mean_static_bins[i][j] = np.nanmean(annual_static_binned_stats[:,i,j])
        mean_advected_bins[i][j] = np.nanmean(annual_advected_binned_stats[:,i,j])

np.save(f'/home/htweedie/melt_ponds/data/binned_stats/static_mean_bins.npy', mean_static_bins)
np.save(f'/home/htweedie/melt_ponds/data/binned_stats/advected_mean_bins.npy', mean_advected_bins)
# Out:
# Processing 2010...
# Loaded MISR data
# /tmp/ipykernel_184413/1778887853.py:32: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/1778887853.py:46: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# Processing 2011...
# Loaded MISR data
# /tmp/ipykernel_184413/1778887853.py:32: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/1778887853.py:46: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# Processing 2017...
# Loaded MISR data
# /tmp/ipykernel_184413/1778887853.py:32: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/1778887853.py:46: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# Processing 2018...
# Loaded MISR data
# /tmp/ipykernel_184413/1778887853.py:32: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/1778887853.py:46: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# Processing 2019...
# Loaded MISR data
# /tmp/ipykernel_184413/1778887853.py:32: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/1778887853.py:46: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# Processing 2020...
# Loaded MISR data
# /tmp/ipykernel_184413/1778887853.py:32: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/1778887853.py:46: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# /tmp/ipykernel_184413/1778887853.py:65: RuntimeWarning: Mean of empty slice
#   mean_static_bins[i][j] = np.nanmean(annual_static_binned_stats[:,i,j])
# /tmp/ipykernel_184413/1778887853.py:66: RuntimeWarning: Mean of empty slice
#   mean_advected_bins[i][j] = np.nanmean(annual_advected_binned_stats[:,i,j])

# %% [markdown]
# ### Calculate mean binned stats and plot:

# %%
mean_static_bins =  np.load('/home/htweedie/melt_ponds/data/binned_stats/static_mean_bins.npy')
mean_advected_bins =  np.load('/home/htweedie/melt_ponds/data/binned_stats/advected_mean_bins.npy')

# %%
fig = plt.figure(figsize=(15,6))

plt.subplot(121)
plot_bins(mean_static_bins*100, 'cubehelix_r', 0, 60, f'Static', 16, 20, colorbar=True, colorbar_title='Melt-pond fraction, %')

plt.subplot(122)
plot_bins(mean_advected_bins*100, 'cubehelix_r', 0, 60, f'Advected', 16, 20, colorbar=True, colorbar_title='Melt-pond fraction, %')

plt.subplots_adjust(top=0.8)
plt.suptitle(f'Mean of all years', fontsize=24)
plt.show()
# Out:
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()

# %% [markdown]
# ### Calculate MPF predictions for pre-defined year and plot:

# %%
# define latitude and roughness bin edges
lat_edges = np.linspace(60, 90, num=31)  # 30 latitude bins
misr_edges = np.linspace(0, 0.5, num=20)  # 20 roughness bins

# get the bin indices and replace out-of-range indices with nans
lat_values = lat_MISR.ravel()
lat_indices = np.digitize(lat_values, lat_edges)
lat_indices = np.where((lat_indices == 0) | (lat_indices == len(lat_edges)), np.nan, lat_indices)

# List of values
misr_values_static = april_MISR.ravel()
misr_indices_static = np.digitize(misr_values_static, misr_edges)
misr_values_advected = mean_advected_MISR.ravel()
misr_indices_advected = np.digitize(misr_values_advected, misr_edges)

# # Replace out-of-range indices with nan
misr_indices_static = np.where((misr_indices_static == 0) | (misr_indices_static == len(misr_edges)), np.nan, misr_indices_static)
misr_indices_advected = np.where((misr_indices_advected == 0) | (misr_indices_advected == len(misr_edges)), np.nan, misr_indices_advected)

# %%
# for each position in 1000x1000 flattened array look at latitude and roughness ... then use collated data to predict an average for that point
predicted_mpf_static = np.zeros(1000000)
for i in range(1000000):
    current_misr_index = misr_indices_static[i]
    current_lat_index = lat_indices[i]
    if not (np.isnan(current_misr_index) or np.isnan(current_lat_index)):
        predicted_mpf_static[i] = mean_static_bins[current_lat_index.astype(int)][current_misr_index.astype(int)]
    else:
        predicted_mpf_static[i] = np.nan

predicted_mpf_advected = np.zeros(1000000)
for i in range(1000000):
    current_misr_index = misr_indices_advected[i]
    current_lat_index = lat_indices[i]
    if not (np.isnan(current_misr_index) or np.isnan(current_lat_index)):
        predicted_mpf_advected[i] = mean_advected_bins[current_lat_index.astype(int)][current_misr_index.astype(int)]
    else:
        predicted_mpf_advected[i] = np.nan

# We have created a faux mpf dataset for the specified year. 
# Data will be missing where data is missing in the roughness

# %% [markdown]
# Static:

# %%
fig = plt.figure(figsize=(12,5))

predicted_year_average = calculate_binned_averages(predicted_mpf_static, april_MISR.flatten(), lat_MISR)

plt.subplot(121)
plot_bins(predicted_year_average, 'cubehelix_r', 0, 0.6, f'Predicted MPF, {YEAR}', label_size=16, title_size=20)

plt.subplot(122)
plot_bins(static_binned_stats, 'cubehelix_r', 0, 0.6, f'Observed MPF, {YEAR}', label_size=16, title_size=20)

fig.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()

# %% [markdown]
# Advected:

# %%
fig = plt.figure(figsize=(12,5))

predicted_year_average = calculate_binned_averages(predicted_mpf_advected, mean_advected_MISR.flatten(), lat_MISR)

plt.subplot(121)
plot_bins(predicted_year_average, 'cubehelix_r', 0, 0.6, f'Predicted MPF, {YEAR}', label_size=16, title_size=20)

plt.subplot(122)
plot_bins(advected_binned_stats, 'cubehelix_r', 0, 0.6, f'Observed MPF, {YEAR}', label_size=16, title_size=20)

fig.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()

# %% [markdown]
# ### Plot predicted and observed MPF for all years with advected SIR:

# %%
# retrieve all observed MPFs:
YEARS = [2010, 2011, 2017, 2018, 2019, 2020]
all_observed_mpfs = np.zeros((len(YEARS), 1000000))

for y in range(len(YEARS)):
    year_mpf,_,_,_,_ = load_observed_mpf(YEARS[y], x_MISR, y_MISR)
    all_observed_mpfs[y,:] = year_mpf.reshape(1000000) 

overall_mean_observed_mpfs = np.nanmean(all_observed_mpfs, axis=0)
np.shape(overall_mean_observed_mpfs)
# Out:
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3525758123.py:9: RuntimeWarning: Mean of empty slice
#   overall_mean_observed_mpfs = np.nanmean(all_observed_mpfs, axis=0)
# (1000000,)

# %% [markdown]
# Static:

# %%
YEARS = [2010, 2011, 2017, 2018, 2019, 2020]

all_static_predictions = np.zeros((len(YEARS), 1000000))
results_static = np.zeros((len(YEARS), 3))
fig = plt.figure(figsize=(12,20))

for y in range(len(YEARS)):
    year = YEARS[y] 

    april_MISR, lon_MISR, lat_MISR, x_MISR, y_MISR = load_static_MISR(year)
    mean_observed_mpf, lon_mpf, lat_mpf, x_mpf, y_mpf = load_observed_mpf(year, x_MISR, y_MISR)

    predicted_mpf_static = predict_mpf(april_MISR, lat_MISR, mean_static_bins)
    all_static_predictions[y] = predicted_mpf_static.ravel()

    observed_year_average = calculate_binned_averages(mean_observed_mpf, april_MISR, lat_MISR)
    predicted_year_average = calculate_binned_averages(predicted_mpf_static, april_MISR, lat_MISR)   

    results_static[y,0] = np.nanmean(predicted_year_average)
    results_static[y,1] = np.nanmean(observed_year_average)
    results_static[y,2] = np.nanmean((np.square(predicted_year_average - observed_year_average)))

    plt.subplot(6,3,y*3+1)
    plot_bins(predicted_year_average, 'cubehelix_r', 0, 0.6, f'Predicted MPF, {year}', label_size=10, title_size=12)

    plt.subplot(6,3,y*3+2)
    plot_bins(observed_year_average, 'cubehelix_r', 0, 0.6, f'Observed MPF, {year}', label_size=10, title_size=12)

    plt.subplot(6,3,y*3+3)
    plot_bins(perc_diff(predicted_year_average, observed_year_average), 'seismic', -100, 100, f'% diff between predicted and observed', label_size=10, title_size=12)

# Show the plot
fig.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()

# %% [markdown]
# Advected:

# %%
YEARS = [2010, 2011, 2017, 2018, 2019, 2020]

all_advected_predictions = np.zeros((len(YEARS), 1000000))
results_advected = np.zeros((6,3))
fig = plt.figure(figsize=(12,20))

for y in range(len(YEARS)):
    year = YEARS[y] 

    april_MISR, lon_MISR, lat_MISR, x_MISR, y_MISR = load_static_MISR(year)
    mean_observed_mpf, lon_mpf, lat_mpf, x_mpf, y_mpf = load_observed_mpf(year, x_MISR, y_MISR)
    mean_advected_MISR = load_advected_MISR(YEAR)

    predicted_mpf_advected = predict_mpf(mean_advected_MISR, lat_MISR, mean_advected_bins)
    all_advected_predictions[y] = predicted_mpf_advected.ravel()

    observed_year_average = calculate_binned_averages(mean_observed_mpf, mean_advected_MISR, lat_MISR)
    predicted_year_average = calculate_binned_averages(predicted_mpf_advected, mean_advected_MISR, lat_MISR)   

    results_advected[y,0] = np.nanmean(predicted_year_average)
    results_advected[y,1] = np.nanmean(observed_year_average)
    results_advected[y,2] = np.nanmean((np.square(predicted_year_average - observed_year_average)))

    plt.subplot(6,3,y*3+1)
    plot_bins(predicted_year_average, 'cubehelix_r', 0, 0.6, f'Predicted MPF, {year}', label_size=10, title_size=12)

    plt.subplot(6,3,y*3+2)
    plot_bins(observed_year_average, 'cubehelix_r', 0, 0.6, f'Observed MPF, {year}', label_size=10, title_size=12)

    plt.subplot(6,3,y*3+3)
    plot_bins(perc_diff(predicted_year_average, observed_year_average), 'seismic', -100, 100, f'% diff between predicted and observed', label_size=10, title_size=12)

# Show the plot
fig.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_184413/3262667830.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:96: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()
# /tmp/ipykernel_184413/3262667830.py:150: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar()

# %%
YEARS = [2010, 2011, 2017, 2018, 2019, 2020]

fig = plt.figure(figsize=(12, 20))
plt.set_cmap('cubehelix_r')

for y in range(len(YEARS)):

    year = YEARS[y]

    ax = fig.add_subplot(6,3,y*3+1)
    ax.set_title(f'Predicted summer MPF, static, {year}')
    m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')
    lon_map, lat_map = m(lon_MISR, lat_MISR)
    m.drawcoastlines()
    m.drawparallels(np.arange(-80.,81.,20.))
    m.drawmeridians(np.arange(-180.,181.,20.))

    m.pcolormesh(lon_map, lat_map, all_static_predictions[y].reshape(1000,1000)*100, vmin=0, vmax=60)
    cbar=plt.colorbar(shrink=0.5, ticks = [0, 20, 40, 60])
    cbar.set_label('Melt pond fraction, %')


    ax = fig.add_subplot(6,3,y*3+2)
    ax.set_title(f'Predicted summer MPF, advected, {year}')
    m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')
    m.drawcoastlines()
    m.drawparallels(np.arange(-80.,81.,20.))
    m.drawmeridians(np.arange(-180.,181.,20.))

    m.pcolormesh(lon_map, lat_map, all_advected_predictions[y].reshape(1000,1000)*100, vmin=0, vmax=60)
    cbar=plt.colorbar(shrink=0.5, ticks = [0, 20, 40, 60])
    cbar.set_label('Melt pond fraction, %')


    ax = fig.add_subplot(6,3,y*3+3)
    ax.set_title(f'Observed summer MPF, {year}')
    m = Basemap(projection='npstere',boundinglat=55,lon_0=0,resolution='l')
    m.drawcoastlines()
    m.drawparallels(np.arange(-80.,81.,20.))
    m.drawmeridians(np.arange(-180.,181.,20.))

    m.pcolormesh(lon_map, lat_map, all_observed_mpfs[y].reshape(1000,1000)*100, vmin=0, vmax=60)
    cbar=plt.colorbar(shrink=0.4, ticks = [0, 20, 40, 60])
    cbar.set_label('Melt pond fraction, %')


plt.show()
# Out:
# /tmp/ipykernel_184413/2733800047.py:18: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_static_predictions[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:30: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_advected_predictions[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:42: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_observed_mpfs[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:18: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_static_predictions[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:30: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_advected_predictions[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:42: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_observed_mpfs[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:18: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_static_predictions[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:30: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_advected_predictions[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:42: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_observed_mpfs[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:18: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_static_predictions[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:30: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_advected_predictions[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:42: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_observed_mpfs[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:18: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_static_predictions[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:30: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_advected_predictions[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:42: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_observed_mpfs[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:18: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_static_predictions[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:30: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_advected_predictions[y].reshape(1000,1000)*100, vmin=0, vmax=60)
# /tmp/ipykernel_184413/2733800047.py:42: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   m.pcolormesh(lon_map, lat_map, all_observed_mpfs[y].reshape(1000,1000)*100, vmin=0, vmax=60)

# %% [markdown]
# ### Leave-one-out analysis:

# %%
YEARS = [2010, 2011, 2017, 2018, 2019, 2020]

# initialise empty arrays
observed_mpfs = np.zeros(((len(YEARS)), 1000, 1000))
adv_pred = np.zeros(((len(YEARS)), 1000, 1000))
stat_pred = np.zeros(((len(YEARS)), 1000, 1000))
adv_obs_mpf_subset = []
adv_pred_subset = []
stat_obs_mpf_subset = []
stat_pred_subset = []
adv_pred_bins = np.zeros(((len(YEARS)), 30, 20))
stat_pred_bins = np.zeros(((len(YEARS)), 30, 20))
adv_corr_coeffs = np.zeros(len(YEARS))
stat_corr_coeffs = np.zeros(len(YEARS))

for i in range(len(YEARS)):
    year = YEARS[i]

    # load static and advected SIR and observed MPF
    april_MISR, lon_MISR, lat_MISR, x_MISR, y_MISR = load_static_MISR(year)
    mean_advected_MISR = load_advected_MISR(year)
    mean_observed_mpf,_,_,_,_ = load_observed_mpf(year, x_MISR, y_MISR)

    # calculate mean bins for years not excluded then use them to predict MPF for static and advected SIT
    excl_mean_static_bins, excl_mean_advected_bins = calc_excl_bin_means(year)
    static_predicted_mpf = predict_mpf(april_MISR, lat_MISR, excl_mean_static_bins)
    advected_predicted_mpf = predict_mpf(mean_advected_MISR, lat_MISR, excl_mean_advected_bins)

    observed_mpfs[i,:,:] = mean_observed_mpf.reshape(1000,1000)
    adv_pred[i,:,:] = advected_predicted_mpf.reshape(1000,1000)
    stat_pred[i,:,:] = static_predicted_mpf.reshape(1000,1000)
    adv_pred_bins[i,:,:] = calculate_binned_averages(advected_predicted_mpf, mean_advected_MISR, lat_MISR)
    stat_pred_bins[i,:,:] = calculate_binned_averages(static_predicted_mpf, mean_advected_MISR, lat_MISR)

    # subset static and advected observations and predictions for calculating correlations
    stat_valid_indices = ~np.isnan(static_predicted_mpf) & ~np.isnan(mean_observed_mpf)
    stat_mpf_sub = mean_observed_mpf[stat_valid_indices]
    stat_pred_sub = static_predicted_mpf[stat_valid_indices]
    stat_obs_mpf_subset.append(stat_mpf_sub)
    stat_pred_subset.append(stat_pred_sub)

    adv_valid_indices = ~np.isnan(advected_predicted_mpf) & ~np.isnan(mean_observed_mpf)
    adv_mpf_sub = mean_observed_mpf[adv_valid_indices]
    adv_pred_sub = advected_predicted_mpf[adv_valid_indices]
    adv_obs_mpf_subset.append(adv_mpf_sub)
    adv_pred_subset.append(adv_pred_sub)

    # calculate correlation coefficients
    stat_corr_coeffs[i] = np.corrcoef(stat_mpf_sub, stat_pred_sub)[0,1]
    adv_corr_coeffs[i] = np.corrcoef(adv_mpf_sub, adv_pred_sub)[0,1]

# save all data for visualising elsewhere
path = '/home/htweedie/melt_ponds/processed_results'
np.save(f'{path}/observed_mpfs.npy', observed_mpfs)
np.save(f'{path}/adv_pred.npy', adv_pred)
np.save(f'{path}/stat_pred.npy', stat_pred)
np.save(f'{path}/adv_pred_bins.npy', adv_pred_bins)
np.save(f'{path}/stat_pred_bins.npy', stat_pred_bins)
np.save(f'{path}/adv_corr_coeffs.npy', adv_corr_coeffs)
np.save(f'{path}/stat_corr_coeffs.npy', stat_corr_coeffs)
write_list(f'{path}/adv_obs_mpf_subset.pkl', adv_obs_mpf_subset)
write_list(f'{path}/adv_pred_subset.pkl', adv_pred_subset)
write_list(f'{path}/stat_obs_mpf_subset.pkl', stat_obs_mpf_subset)
write_list(f'{path}/stat_pred_subset.pkl', stat_pred_subset)
# Out:
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/2319480953.py:26: RuntimeWarning: Mean of empty slice
#   mean_static_bins[i][j] = np.nanmean(annual_static_binned_stats[:,i,j])
# /tmp/ipykernel_85524/2319480953.py:27: RuntimeWarning: Mean of empty slice
#   mean_advected_bins[i][j] = np.nanmean(annual_advected_binned_stats[:,i,j])
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/2319480953.py:26: RuntimeWarning: Mean of empty slice
#   mean_static_bins[i][j] = np.nanmean(annual_static_binned_stats[:,i,j])
# /tmp/ipykernel_85524/2319480953.py:27: RuntimeWarning: Mean of empty slice
#   mean_advected_bins[i][j] = np.nanmean(annual_advected_binned_stats[:,i,j])
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/2319480953.py:26: RuntimeWarning: Mean of empty slice
#   mean_static_bins[i][j] = np.nanmean(annual_static_binned_stats[:,i,j])
# /tmp/ipykernel_85524/2319480953.py:27: RuntimeWarning: Mean of empty slice
#   mean_advected_bins[i][j] = np.nanmean(annual_advected_binned_stats[:,i,j])
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/2319480953.py:26: RuntimeWarning: Mean of empty slice
#   mean_static_bins[i][j] = np.nanmean(annual_static_binned_stats[:,i,j])
# /tmp/ipykernel_85524/2319480953.py:27: RuntimeWarning: Mean of empty slice
#   mean_advected_bins[i][j] = np.nanmean(annual_advected_binned_stats[:,i,j])
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/2319480953.py:26: RuntimeWarning: Mean of empty slice
#   mean_static_bins[i][j] = np.nanmean(annual_static_binned_stats[:,i,j])
# /tmp/ipykernel_85524/2319480953.py:27: RuntimeWarning: Mean of empty slice
#   mean_advected_bins[i][j] = np.nanmean(annual_advected_binned_stats[:,i,j])
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:57: RuntimeWarning: Mean of empty slice
#   mean_observed_mpf = np.nanmean(summer_observed_mpf, axis=0).reshape(896,608)
# /tmp/ipykernel_85524/753743875.py:4: FutureWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x, y = pyproj.transform(proj_WGS84, proj_EASE2N, lon, lat)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/2319480953.py:26: RuntimeWarning: Mean of empty slice
#   mean_static_bins[i][j] = np.nanmean(annual_static_binned_stats[:,i,j])
# /tmp/ipykernel_85524/2319480953.py:27: RuntimeWarning: Mean of empty slice
#   mean_advected_bins[i][j] = np.nanmean(annual_advected_binned_stats[:,i,j])
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
# /tmp/ipykernel_85524/753743875.py:116: RuntimeWarning: Mean of empty slice
#   return np.nanmean(x)
